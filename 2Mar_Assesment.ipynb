# %% [raw]
# Matplotlib is a open source data visualization liabrary in Python that provides variety of ploting tools for creating high quality visualizations.
#
# Matplotlib's Pyplot module is a collection of functions that allow users to create different types of plots
# ->Line Plot : A basic plot that displays data as a series of points connected by lines
# -> Bar Plot : A plot that displays data as rectangular bars
# -> Scatter Plot : A plot that displays data as a collection of points , with the position of each point determined by its x and y values
# -> Histogram : A plot tha t displays the distribution of a dataset by grouping data into bins and displaying the no of observations in each bin
# -> Box Plot : A plot that dispalys the distribution into quartiles, with the whiskers extending to show range of the data

# %% [raw]
# Scatter plot is a type of plot in which data is displayed as a collection of points, with the position of each point determined by its x and y values. It is useful for visualizing the relationship between two variables, such as their correlation or clustering. Scatter plots can also be customized with various markers, colors, and sizes to highlight different aspects of the data.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
np.random.seed(3)
x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x))

# %%
plt.scatter(x,y)
plt.xlabel("X axis")
plt.ylabel("Y axis")
plt.title("Scatter ploting")
# Out:
# Text(0.5, 1.0, 'Scatter ploting')

# %% [raw]
# A bar plot, also known as a bar chart or bar graph, is a type of data visualization that represents data using rectangular bars with lengths proportional to the values they represent. The bars can be plotted horizontally or vertically, with the height or width of each bar representing the data values.
#
# Bar plots are used to visually display and compare data across different categories or groups. They are commonly used in statistical analysis, market research, and other fields where data needs to be presented in a clear and concise manner. Bar plots can be used to display numerical data, such as sales figures, population statistics, or survey responses, as well as categorical data, such as types of products, customer demographics, or geographic regions.
#
# One of the key benefits of using bar plots is that they make it easy to see and compare the relative sizes of different data points

# %%
company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])

# %%
plt.bar(company,profit)
plt.title("Bar Ploting")
plt.show()

# %%
plt.barh(company,profit)
plt.title("Horizontal Bar Ploting")
plt.show()

# %% [raw]
# A box plot is a type of data visualization that shows the distribution of numerical data using the five-number summary (minimum, Q1, median, Q3, maximum), with outliers represented by individual points. It is used to compare data across categories, detect skewness and outliers, and identify central tendency and spread. Box plots are widely used in academic research and data analysis.

# %%
box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)

# %%
data = [box1,box2]

# %%
plt.boxplot(data,labels=["Box 1","Box 2"])
plt.ylabel("Value")
plt.title("Box Ploting")
plt.show()
